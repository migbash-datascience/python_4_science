# %% [markdown]
# I got this example on Taylor Exapnsion wth Python [here](https://firsttimeprogrammer.blogspot.com/2015/03/taylor-series-with-python-and-sympy.html)

# %% [markdown]
# First we Install the necessary Libraries & Packages for us to
# use with our program in Python.

# %%
# __________________
# Download the necessary Libraries & Packages
# This is necessary before using them in your projects
# with the syntax 'import...'

# The ! tells the notebook to execute the cell as a shell command.

! pip install sympy numpy matplotlib
# Out:
# ...
#   Using cached numpy-1.18.1-cp37-cp37m-win32.whl (10.8 MB)
# ...

# %% [markdown]
# Here we begin our script:

# %%
# __________________
# Importing Necessary Libraries & Packages

import sympy as sy
from sympy.functions import sin,cos
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("ggplot")

# __________________
# Define the variable and the function to approximate

x = sy.Symbol('x')
f = sin(x)

# __________________
# Factorial function

def factorial(n):
    if n <= 0:
        return 1
    else:
        return n*factorial(n-1)

# __________________
# Taylor approximation at x0 of the function 'function'

def taylor(function,x0,n):
    i = 0
    p = 0
    while i <= n:
        p = p + (function.diff(x,i).subs(x,x0))/(factorial(i))*(x-x0)**i
        i += 1
    return p

# %% [markdown]
# Now we plot our results using the method/function below:

# %%
# __________________
# Plot results

def plot():
    
    x_lims = [-5,5]
    x1 = np.linspace(x_lims[0],x_lims[1],800)
    y1 = []
    
    # Approximate up until 10 starting from 1 and using steps of 2
    for j in range(1,10,2):
        func = taylor(f,0,j)
        print('Taylor expansion at n='+str(j),func)
        for k in x1:
            y1.append(func.subs(x,k))
        plt.plot(x1,y1,label='order '+str(j))
        y1 = []
        
    # Plot the function to approximate (sine, in this case)
    plt.plot(x1,np.sin(x1),label='sin of x')
    plt.xlim(x_lims)
    plt.ylim([-5,5])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.title('Taylor series approximation')
    plt.show()

plot()
# Out:
# Taylor expansion at n=1 x
# Taylor expansion at n=3 -x**3/6 + x
# Taylor expansion at n=5 x**5/120 - x**3/6 + x
# Taylor expansion at n=7 -x**7/5040 + x**5/120 - x**3/6 + x
# Taylor expansion at n=9 x**9/362880 - x**7/5040 + x**5/120 - x**3/6 + x
